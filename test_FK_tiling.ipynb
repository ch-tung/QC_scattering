# %%
from FK import *
import pyvoro
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
plt.rcParams["font.family"] = "Arial"

# %%
# %matplotlib widget

# %% [markdown]
# ## Define unit cells

# %% [markdown]
# ### Triangular unit cell

# %%
c_wht, c_blu, c_ylw = unitcell_TR1([0,0,0], 0)

# %%
c_tile = tile_TR1([0,0,0], 0)

# %%
fig = plt.figure(figsize=(4,4))
fig.tight_layout()
ax = fig.add_subplot(projection='3d')
ax.set_box_aspect([1.2,1.2,1])
ax.view_init(elev=40, azim=-70)

# plot particles
ax.scatter(c_wht[:,0],c_wht[:,1],c_wht[:,2],
           marker='o',c='#808080',s=500)
ax.scatter(c_blu[:,0],c_blu[:,1],c_blu[:,2],
           marker='o',c='b',s=500)
ax.scatter(c_ylw[:,0],c_ylw[:,1],c_ylw[:,2],
           marker='o',c='#FFC000',s=500)

# plot tiles
collection_tile = Poly3DCollection(c_tile, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)
ax.add_collection3d(collection_tile)


ax.set_zticks([0,1])
ax.set_zticklabels([0,r'$l_c$'])
ax.set_xticks([0,1])
ax.set_yticks([0,1])
ax.set_xlim(-0.1,1.1)
ax.set_ylim(-0.1,1.1)
ax.set_zlim(0,1)
ax.tick_params(direction='in', axis='both', which='both', labelsize=24, pad=10)
plt.show()

# %%
c_wht, c_blu, c_ylw = unitcell_TR2([0,0,0], 0)
c_tile = tile_TR1([0,0,0], 0)

# %%
fig = plt.figure(figsize=(4,4))
fig.tight_layout()
ax = fig.add_subplot(projection='3d')
ax.set_box_aspect([1.2,1.2,1])
ax.view_init(elev=40, azim=-70)

# plot particles
ax.scatter(c_wht[:,0],c_wht[:,1],c_wht[:,2],
           marker='o',c='#808080',s=500)
ax.scatter(c_blu[:,0],c_blu[:,1],c_blu[:,2],
           marker='o',c='b',s=500)
ax.scatter(c_ylw[:,0],c_ylw[:,1],c_ylw[:,2],
           marker='o',c='#FFC000',s=500)

# plot tiles
collection_tile = Poly3DCollection(c_tile, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)
ax.add_collection3d(collection_tile)


ax.set_zticks([0,1])
ax.set_zticklabels([0,r'$l_c$'])
ax.set_xticks([0,1])
ax.set_yticks([0,1])
ax.set_xlim(-0.1,1.1)
ax.set_ylim(-0.1,1.1)
ax.set_zlim(0,1)
ax.tick_params(direction='in', axis='both', which='both', labelsize=24, pad=10)
plt.show()

# %% [markdown]
# ### Square unit cell

# %%
c_wht, c_blu, c_ylw = unitcell_SQ([0,0,0], 0)
c_tile = tile_SQ([0,0,0], 0)

# %%
fig = plt.figure(figsize=(4,4))
fig.tight_layout()
ax = fig.add_subplot(projection='3d')
ax.set_box_aspect([1.2,1.2,1])
ax.view_init(elev=40, azim=-70)

# plot particles
ax.scatter(c_wht[:,0],c_wht[:,1],c_wht[:,2],
           marker='o',c='#808080',s=500)
ax.scatter(c_blu[:,0],c_blu[:,1],c_blu[:,2],
           marker='o',c='b',s=500)
ax.scatter(c_ylw[:,0],c_ylw[:,1],c_ylw[:,2],
           marker='o',c='#FFC000',s=500)

# plot tiles
collection_tile = Poly3DCollection(c_tile, facecolors='m', linewidths=1, edgecolors='k', alpha=.75)
ax.add_collection3d(collection_tile)


ax.set_zticks([0,1])
ax.set_zticklabels([0,r'$l_c$'])
ax.set_xticks([0,1])
ax.set_yticks([0,1])
ax.set_xlim(-0.1,1.1)
ax.set_ylim(-0.1,1.1)
ax.set_zlim(0,1)
ax.tick_params(direction='in', axis='both', which='both', labelsize=24, pad=10)
plt.show()

# %% [markdown]
# ### FK sigma phase primitive unit cell

# %%
c_wht, c_blu, c_ylw = c_sigma_unit([0,0,0], Ratio_ca=1.9, PBC=False)
c_SQ, c_TR1, c_TR2 = tile_sigma_unit([0,0,0],Ratio_ca=1.9,PBC=False)

# %%
fig = plt.figure(figsize=(4,4))
fig.tight_layout()
ax = fig.add_subplot(projection='3d')
ax.set_box_aspect([3,3,1])
ax.view_init(elev=90, azim=-90)

# plot particles
ax.scatter(c_wht[:,0],c_wht[:,1],c_wht[:,2],
           marker='o',c='#808080',s=50)
ax.scatter(c_blu[:,0],c_blu[:,1],c_blu[:,2],
           marker='o',c='b',s=50)
ax.scatter(c_ylw[:,0],c_ylw[:,1],c_ylw[:,2],
           marker='o',c='#FFC000',s=50)

# plot tiles
collection_tile_SQ = Poly3DCollection(c_SQ, facecolors='m', linewidths=1, edgecolors='k', alpha=.75)
collection_tile_TR1 = Poly3DCollection(c_TR1, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)
collection_tile_TR2 = Poly3DCollection(c_TR2, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)

ax.add_collection3d(collection_tile_SQ)
ax.add_collection3d(collection_tile_TR1)
ax.add_collection3d(collection_tile_TR2)

ax.set_zticks([])
ax.set_xlim(-0.5,2.5)
ax.set_ylim(-0.5,2.5)
ax.set_zlim(0,1)
plt.show()

# %% [markdown]
# ### Pack the FK sigma phase unit cells

# %%
n_x = 2
n_y = 2
n_layers = 1
r_ca = 1*np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)
r = 1/r_ca
l_c = 1*np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)*r

c_layer_sigma = c_sigma(n_x+1,n_y+1,Ratio_ca=1/r)
points = [c+np.array([-r_ca,0,0]) for c in c_layer_sigma]
i_points = [(p[:,0]>-0.3)*(p[:,1]<4.15) for p in points]
points = [points[i][i_points[i],:] for i in range(len(i_points))]
c_SQ_layer_sigma, c_TR1_layer_sigma, c_TR2_layer_sigma = tile_sigma(n_x,n_y,Ratio_ca=1/r)

# plotting
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(projection='3d')
ax.set_proj_type('ortho')
ax.view_init(elev=90, azim=-90)

# plot particles
ax.scatter(points[0][:,0],points[0][:,1],points[0][:,2],
           marker='o',c='#808080',s=100,alpha=1, edgecolors='k')
ax.scatter(points[1][:,0],points[1][:,1],points[1][:,2],
           marker='o',c='b',s=100,alpha=1, edgecolors='k')
ax.scatter(points[2][:,0],points[2][:,1],points[2][:,2],
           marker='o',c='#FFC000',s=100,alpha=1, edgecolors='k')

# plot tiles
collection_tile_SQ = Poly3DCollection(c_SQ_layer_sigma, facecolors='m', linewidths=1, edgecolors='k', alpha=.75)
collection_tile_TR1 = Poly3DCollection(c_TR1_layer_sigma, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)
collection_tile_TR2 = Poly3DCollection(c_TR2_layer_sigma, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)

ax.add_collection3d(collection_tile_SQ)
ax.add_collection3d(collection_tile_TR1)
ax.add_collection3d(collection_tile_TR2)


ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
# Transparent spines
ax.xaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.set_xlim(-0.5,np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)*n_x+0.5)
ax.set_ylim(-0.5,np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)*n_y+0.5)
ax.set_zlim(0,1)
ax.set_box_aspect([np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)*n_x+1,np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)*n_y+1,1])

plt.tight_layout(pad=0)
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
n_x = 8
n_y = 8
n_layers = 1
r_ca = 1*np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)
r = 1/r_ca
l_c = 1*np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)*r

c_layer_A15 = c_A15(n_x,n_y,Ratio_ca=1/r)
points = np.vstack(c_layer_A15)
c_SQ_layer_A15, c_TR1_layer_A15, c_TR2_layer_A15 = tile_A15(n_x,n_y,Ratio_ca=1/r)

# plotting
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(projection='3d')
ax.set_proj_type('ortho')
ax.view_init(elev=90, azim=-90)

# plot particles
ax.scatter(points[:,0],points[:,1],points[:,2],
           marker='o',c='k',s=20)

# plot tiles
collection_tile_SQ = Poly3DCollection(c_SQ_layer_A15, facecolors='m', linewidths=1, edgecolors='k', alpha=.75)
collection_tile_TR1 = Poly3DCollection(c_TR1_layer_A15, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)
collection_tile_TR2 = Poly3DCollection(c_TR2_layer_A15, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)

ax.add_collection3d(collection_tile_SQ)
ax.add_collection3d(collection_tile_TR1)
ax.add_collection3d(collection_tile_TR2)


ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
# Transparent spines
ax.xaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.set_xlim(-0.5,n_x+0.5)
ax.set_ylim(-0.5,n_y+0.5)
ax.set_zlim(0,1)
ax.set_box_aspect([n_x+1,n_y+1,1])

plt.tight_layout(pad=-5)
plt.show()

# %%
n_x = 8
n_y = 5
n_layers = 1
r_ca = 1*np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)
r = 1/r_ca
l_c = 1*np.sqrt((1+np.sqrt(3)/2)**2+0.5**2)*r

c_layer_Z = c_Z(n_x,n_y,Ratio_ca=1/r)
points = np.vstack(c_layer_Z)
c_SQ_layer_Z, c_TR1_layer_Z, c_TR2_layer_Z = tile_Z(n_x,n_y,Ratio_ca=1/r)

# plotting
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(projection='3d')
ax.set_proj_type('ortho')
ax.view_init(elev=90, azim=-90)

# plot particles
ax.scatter(points[:,0],points[:,1],points[:,2],
           marker='o',c='k',s=20)

# plot tiles
collection_tile_SQ = Poly3DCollection(c_SQ_layer_Z, facecolors='m', linewidths=1, edgecolors='k', alpha=.75)
collection_tile_TR1 = Poly3DCollection(c_TR1_layer_Z, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)
collection_tile_TR2 = Poly3DCollection(c_TR2_layer_Z, facecolors='c', linewidths=1, edgecolors='k', alpha=.75)

ax.add_collection3d(collection_tile_SQ)
ax.add_collection3d(collection_tile_TR1)
ax.add_collection3d(collection_tile_TR2)


ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
# Transparent spines
ax.xaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.set_xlim(-0.5,n_x+0.5)
ax.set_ylim(-0.5,n_y*np.sqrt(3)+0.5)
ax.set_zlim(0,1)
ax.set_box_aspect([n_x+1,n_y*np.sqrt(3)+1,1])

plt.tight_layout(pad=-5)
plt.show()

# %%
c_SQ_layer_sigma[:],0
# Out:
# ([[[0.0, 0.0, 0.0],
#    [-0.2588190451025207, 0.9659258262890682, 0.0],
#    [0.7071067811865475, 1.224744871391589, 0.0],
#    [0.9659258262890682, 0.25881904510252074, 0.0]],
#   [[1.6730326074756157, 0.9659258262890682, 0.0],
#    [0.7071067811865475, 1.224744871391589, 0.0],
#    [0.9659258262890682, 2.190670697680657, 0.0],
#    [1.9318516525781366, 1.9318516525781364, 0.0]],
#   [[0.0, 1.9318516525781366, 0.0],
#    [-0.2588190451025207, 2.897777478867205, 0.0],
#    [0.7071067811865475, 3.156596523969726, 0.0],
#    [0.9659258262890682, 2.190670697680657, 0.0]],
#   [[1.6730326074756157, 2.897777478867205, 0.0],
#    [0.7071067811865475, 3.156596523969726, 0.0],
#    [0.9659258262890682, 4.1225223502587935, 0.0],
#    [1.9318516525781366, 3.863703305156273, 0.0]],
#   [[1.9318516525781366, 0.0, 0.0],
#    [1.6730326074756159, 0.9659258262890682, 0.0],
#    [2.6389584337646843, 1.224744871391589, 0.0],
#    [2.897777478867205, 0.25881904510252074, 0.0]],
#   [[3.604884260053752, 0.9659258262890682, 0.0],
#    [2.6389584337646843, 1.224744871391589, 0.0],
#    [2.897777478867205, 2.190670697680657, 0.0],
#    [3.8637033051562732, 1.9318516525781364, 0.0]],
#   [[1.9318516525781366, 1.9318516525781366, 0.0],
#    [1.6730326074756159, 2.897777478867205, 0.0],
#    [2.6389584337646843, 3.156596523969726, 0.0],
#    [2.897777478867205, 2.190670697680657, 0.0]],
#   [[3.604884260053752, 2.897777478867205, 0.0],
#    [2.6389584337646843, 3.156596523969726, 0.0],
#    [2.897777478867205, 4.1225223502587935, 0.0],
#    [3.8637033051562732, 3.863703305156273, 0.0]]],
#  0)
